# %%
import numpy as np
import pandas
import os
from tabulate import tabulate

# %%
def cal_score(arr):
    ans = 0
    for i in range(0,len(arr)):
        for j in range(i+1,len(arr)):
            node1 = i+1
            node2 = j+1
            trueEdge = dict.get((node1,node2),0)
            if arr[i]!=arr[j] and trueEdge == 1:
                ans += 1
    return -ans

# %%
# tournament selection
def selection(pop, scores, k=3):
	# first random selection
	selection_ix = np.random.randint(len(pop))
	for ix in np.random.randint(0, len(pop), k-1):
		# check if better (e.g. perform a tournament)
		if scores[ix] < scores[selection_ix]:
			selection_ix = ix
	return pop[selection_ix]

# %%
# crossover two parents to create two children
def crossover(p1, p2, r_cross):
	# children are copies of parents by default
	c1, c2 = p1.copy(), p2.copy()
	# check for recombination
	if np.random.rand() < r_cross:
		# select crossover point that is not on the end of the string
		pt = np.random.randint(1, len(p1)-2)
		# perform crossover
		c1 = p1[:pt] + p2[pt:]
		c2 = p2[:pt] + p1[pt:]
	return [c1, c2]

# %%
# mutation operator
def mutation(bitstring, r_mut):
	for i in range(len(bitstring)):
		# check for a mutation
		if np.random.rand() < r_mut:
			# flip the bit
			bitstring[i] = 1 - bitstring[i]

# %%
def GA(cal_score, n_bits, n_loop, n_pop, r_cross, r_mut):
    pop = [np.random.randint(0, 2, n_bits).tolist() for _ in range(n_pop)]

    best, best_eval = 0, cal_score(pop[0])

    for gen in range(n_loop):
        scores = [cal_score(_) for _ in pop]
        for i in range(n_pop):
            if scores[i] < best_eval:
                best, best_eval = pop[i], scores[i]
                # print(">%d, new best f(%s) = %.3f" % (gen,  pop[i], scores[i]))

        selected = [selection(pop, scores) for _ in range(n_pop)]

        children = list()
        for i in range(0, n_pop, 2):
            par1, par2 = selected[i], selected[i+1]
            for _ in crossover(par1, par2, r_cross):
                mutation(_, r_mut)
                children.append(_)
        pop = children

    return [best, -best_eval]

# %%
test_directory = './Test'
for item in os.listdir(test_directory):
    item_path = os.path.join(test_directory, item)
    with open(item_path, 'r', encoding='utf-8') as file:
        _ = file.read()
    _ = _.split()
    n, m, optimalValue = int(_[0]), int(_[1]), int(_[2])

    dict = {}
    for i in range(3,len(_),3):
        dict[(int(_[i]),int(_[i+1]))] = int(_[i+2])
        dict[(int(_[i+1]),int(_[i]))] = int(_[i+2])

    n_pop,n_bits = 100, n
    n_loop = 50
    r_cross = 0.9
    r_mut = 1.0/float(n_bits)

    num_node = []
    num_edge = []
    optimalValues = []
    scores = []

    # GA
    for k in range(30):
        best, score = GA(cal_score, n_bits, n_loop, n_pop, r_cross, r_mut)

        optimalValues.append(optimalValue)
        scores.append(score)
        num_node.append(n)
        num_edge.append(m)

    df = pandas.DataFrame({
        # 'Số đỉnh': num_node,
        # 'Số cạnh': num_edge,
        'Giá trị tìm được': scores,
        'Giá trị chính xác': optimalValues
    })

    print("Test ",item)
    print(tabulate(df, headers='keys', tablefmt='grid'))

    sum_scores = sum(scores)
    average_score = float(sum_scores/30)
    percent = 100*(float(optimalValue-average_score)/optimalValue)
    print("Trung bình giá trị tìm được: ",average_score)
    print("Giá trị chính xác: ",optimalValue)
    print("Delta = ",percent,"%")
    print("\n")
# Out:
# Test  g05_100.0
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1402 |                1430 |
# +----+--------------------+---------------------+
# |  1 |               1391 |                1430 |
# +----+--------------------+---------------------+
# |  2 |               1383 |                1430 |
# +----+--------------------+---------------------+
# |  3 |               1398 |                1430 |
# +----+--------------------+---------------------+
# |  4 |               1395 |                1430 |
# +----+--------------------+---------------------+
# |  5 |               1410 |                1430 |
# +----+--------------------+---------------------+
# |  6 |               1387 |                1430 |
# +----+--------------------+---------------------+
# |  7 |               1401 |                1430 |
# +----+--------------------+---------------------+
# |  8 |               1396 |                1430 |
# +----+--------------------+---------------------+
# |  9 |               1385 |                1430 |
# +----+--------------------+---------------------+
# | 10 |               1392 |                1430 |
# +----+--------------------+---------------------+
# | 11 |               1395 |                1430 |
# +----+--------------------+---------------------+
# | 12 |               1387 |                1430 |
# +----+--------------------+---------------------+
# | 13 |               1399 |                1430 |
# +----+--------------------+---------------------+
# | 14 |               1392 |                1430 |
# +----+--------------------+---------------------+
# | 15 |               1411 |                1430 |
# +----+--------------------+---------------------+
# | 16 |               1385 |                1430 |
# +----+--------------------+---------------------+
# | 17 |               1402 |                1430 |
# +----+--------------------+---------------------+
# | 18 |               1390 |                1430 |
# +----+--------------------+---------------------+
# | 19 |               1386 |                1430 |
# +----+--------------------+---------------------+
# | 20 |               1395 |                1430 |
# +----+--------------------+---------------------+
# | 21 |               1385 |                1430 |
# +----+--------------------+---------------------+
# | 22 |               1390 |                1430 |
# +----+--------------------+---------------------+
# | 23 |               1394 |                1430 |
# +----+--------------------+---------------------+
# | 24 |               1405 |                1430 |
# +----+--------------------+---------------------+
# | 25 |               1390 |                1430 |
# +----+--------------------+---------------------+
# | 26 |               1388 |                1430 |
# +----+--------------------+---------------------+
# | 27 |               1403 |                1430 |
# +----+--------------------+---------------------+
# | 28 |               1394 |                1430 |
# +----+--------------------+---------------------+
# | 29 |               1400 |                1430 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1394.3666666666666
# Giá trị chính xác:  1430
# Delta =  2.4918414918414995 %
#
#
# Test  g05_100.1
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1388 |                1425 |
# +----+--------------------+---------------------+
# |  1 |               1402 |                1425 |
# +----+--------------------+---------------------+
# |  2 |               1399 |                1425 |
# +----+--------------------+---------------------+
# |  3 |               1405 |                1425 |
# +----+--------------------+---------------------+
# |  4 |               1401 |                1425 |
# +----+--------------------+---------------------+
# |  5 |               1388 |                1425 |
# +----+--------------------+---------------------+
# |  6 |               1398 |                1425 |
# +----+--------------------+---------------------+
# |  7 |               1406 |                1425 |
# +----+--------------------+---------------------+
# |  8 |               1394 |                1425 |
# +----+--------------------+---------------------+
# |  9 |               1396 |                1425 |
# +----+--------------------+---------------------+
# | 10 |               1413 |                1425 |
# +----+--------------------+---------------------+
# | 11 |               1410 |                1425 |
# +----+--------------------+---------------------+
# | 12 |               1394 |                1425 |
# +----+--------------------+---------------------+
# | 13 |               1396 |                1425 |
# +----+--------------------+---------------------+
# | 14 |               1386 |                1425 |
# +----+--------------------+---------------------+
# | 15 |               1393 |                1425 |
# +----+--------------------+---------------------+
# | 16 |               1403 |                1425 |
# +----+--------------------+---------------------+
# | 17 |               1390 |                1425 |
# +----+--------------------+---------------------+
# | 18 |               1394 |                1425 |
# +----+--------------------+---------------------+
# | 19 |               1391 |                1425 |
# +----+--------------------+---------------------+
# | 20 |               1408 |                1425 |
# +----+--------------------+---------------------+
# | 21 |               1382 |                1425 |
# +----+--------------------+---------------------+
# | 22 |               1399 |                1425 |
# +----+--------------------+---------------------+
# | 23 |               1410 |                1425 |
# +----+--------------------+---------------------+
# | 24 |               1382 |                1425 |
# +----+--------------------+---------------------+
# | 25 |               1395 |                1425 |
# +----+--------------------+---------------------+
# | 26 |               1383 |                1425 |
# +----+--------------------+---------------------+
# | 27 |               1395 |                1425 |
# +----+--------------------+---------------------+
# | 28 |               1392 |                1425 |
# +----+--------------------+---------------------+
# | 29 |               1388 |                1425 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1396.0333333333333
# Giá trị chính xác:  1425
# Delta =  2.032748538011698 %
#
#
# Test  g05_100.2
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1390 |                1432 |
# +----+--------------------+---------------------+
# |  1 |               1393 |                1432 |
# +----+--------------------+---------------------+
# |  2 |               1390 |                1432 |
# +----+--------------------+---------------------+
# |  3 |               1397 |                1432 |
# +----+--------------------+---------------------+
# |  4 |               1392 |                1432 |
# +----+--------------------+---------------------+
# |  5 |               1399 |                1432 |
# +----+--------------------+---------------------+
# |  6 |               1408 |                1432 |
# +----+--------------------+---------------------+
# |  7 |               1411 |                1432 |
# +----+--------------------+---------------------+
# |  8 |               1395 |                1432 |
# +----+--------------------+---------------------+
# |  9 |               1392 |                1432 |
# +----+--------------------+---------------------+
# | 10 |               1389 |                1432 |
# +----+--------------------+---------------------+
# | 11 |               1400 |                1432 |
# +----+--------------------+---------------------+
# | 12 |               1410 |                1432 |
# +----+--------------------+---------------------+
# | 13 |               1384 |                1432 |
# +----+--------------------+---------------------+
# | 14 |               1381 |                1432 |
# +----+--------------------+---------------------+
# | 15 |               1383 |                1432 |
# +----+--------------------+---------------------+
# | 16 |               1375 |                1432 |
# +----+--------------------+---------------------+
# | 17 |               1396 |                1432 |
# +----+--------------------+---------------------+
# | 18 |               1397 |                1432 |
# +----+--------------------+---------------------+
# | 19 |               1408 |                1432 |
# +----+--------------------+---------------------+
# | 20 |               1385 |                1432 |
# +----+--------------------+---------------------+
# | 21 |               1397 |                1432 |
# +----+--------------------+---------------------+
# | 22 |               1401 |                1432 |
# +----+--------------------+---------------------+
# | 23 |               1395 |                1432 |
# +----+--------------------+---------------------+
# | 24 |               1390 |                1432 |
# +----+--------------------+---------------------+
# | 25 |               1386 |                1432 |
# +----+--------------------+---------------------+
# | 26 |               1401 |                1432 |
# +----+--------------------+---------------------+
# | 27 |               1384 |                1432 |
# +----+--------------------+---------------------+
# | 28 |               1396 |                1432 |
# +----+--------------------+---------------------+
# | 29 |               1373 |                1432 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1393.2666666666667
# Giá trị chính xác:  1432
# Delta =  2.7048417132216023 %
#
#
# Test  g05_100.3
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1388 |                1424 |
# +----+--------------------+---------------------+
# |  1 |               1396 |                1424 |
# +----+--------------------+---------------------+
# |  2 |               1397 |                1424 |
# +----+--------------------+---------------------+
# |  3 |               1400 |                1424 |
# +----+--------------------+---------------------+
# |  4 |               1389 |                1424 |
# +----+--------------------+---------------------+
# |  5 |               1406 |                1424 |
# +----+--------------------+---------------------+
# |  6 |               1394 |                1424 |
# +----+--------------------+---------------------+
# |  7 |               1389 |                1424 |
# +----+--------------------+---------------------+
# |  8 |               1394 |                1424 |
# +----+--------------------+---------------------+
# |  9 |               1384 |                1424 |
# +----+--------------------+---------------------+
# | 10 |               1393 |                1424 |
# +----+--------------------+---------------------+
# | 11 |               1383 |                1424 |
# +----+--------------------+---------------------+
# | 12 |               1389 |                1424 |
# +----+--------------------+---------------------+
# | 13 |               1398 |                1424 |
# +----+--------------------+---------------------+
# | 14 |               1395 |                1424 |
# +----+--------------------+---------------------+
# | 15 |               1405 |                1424 |
# +----+--------------------+---------------------+
# | 16 |               1388 |                1424 |
# +----+--------------------+---------------------+
# | 17 |               1397 |                1424 |
# +----+--------------------+---------------------+
# | 18 |               1407 |                1424 |
# +----+--------------------+---------------------+
# | 19 |               1393 |                1424 |
# +----+--------------------+---------------------+
# | 20 |               1388 |                1424 |
# +----+--------------------+---------------------+
# | 21 |               1401 |                1424 |
# +----+--------------------+---------------------+
# | 22 |               1403 |                1424 |
# +----+--------------------+---------------------+
# | 23 |               1397 |                1424 |
# +----+--------------------+---------------------+
# | 24 |               1388 |                1424 |
# +----+--------------------+---------------------+
# | 25 |               1397 |                1424 |
# +----+--------------------+---------------------+
# | 26 |               1390 |                1424 |
# +----+--------------------+---------------------+
# | 27 |               1399 |                1424 |
# +----+--------------------+---------------------+
# | 28 |               1390 |                1424 |
# +----+--------------------+---------------------+
# | 29 |               1395 |                1424 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1394.4333333333334
# Giá trị chính xác:  1424
# Delta =  2.0763108614232166 %
#
#
# Test  g05_100.4
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1409 |                1440 |
# +----+--------------------+---------------------+
# |  1 |               1391 |                1440 |
# +----+--------------------+---------------------+
# |  2 |               1406 |                1440 |
# +----+--------------------+---------------------+
# |  3 |               1408 |                1440 |
# +----+--------------------+---------------------+
# |  4 |               1409 |                1440 |
# +----+--------------------+---------------------+
# |  5 |               1394 |                1440 |
# +----+--------------------+---------------------+
# |  6 |               1398 |                1440 |
# +----+--------------------+---------------------+
# |  7 |               1390 |                1440 |
# +----+--------------------+---------------------+
# |  8 |               1417 |                1440 |
# +----+--------------------+---------------------+
# |  9 |               1400 |                1440 |
# +----+--------------------+---------------------+
# | 10 |               1404 |                1440 |
# +----+--------------------+---------------------+
# | 11 |               1397 |                1440 |
# +----+--------------------+---------------------+
# | 12 |               1405 |                1440 |
# +----+--------------------+---------------------+
# | 13 |               1405 |                1440 |
# +----+--------------------+---------------------+
# | 14 |               1401 |                1440 |
# +----+--------------------+---------------------+
# | 15 |               1413 |                1440 |
# +----+--------------------+---------------------+
# | 16 |               1393 |                1440 |
# +----+--------------------+---------------------+
# | 17 |               1389 |                1440 |
# +----+--------------------+---------------------+
# | 18 |               1401 |                1440 |
# +----+--------------------+---------------------+
# | 19 |               1389 |                1440 |
# +----+--------------------+---------------------+
# | 20 |               1392 |                1440 |
# +----+--------------------+---------------------+
# | 21 |               1398 |                1440 |
# +----+--------------------+---------------------+
# | 22 |               1415 |                1440 |
# +----+--------------------+---------------------+
# | 23 |               1391 |                1440 |
# +----+--------------------+---------------------+
# | 24 |               1400 |                1440 |
# +----+--------------------+---------------------+
# | 25 |               1405 |                1440 |
# +----+--------------------+---------------------+
# | 26 |               1396 |                1440 |
# +----+--------------------+---------------------+
# | 27 |               1395 |                1440 |
# +----+--------------------+---------------------+
# | 28 |               1417 |                1440 |
# +----+--------------------+---------------------+
# | 29 |               1393 |                1440 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1400.7
# Giá trị chính xác:  1440
# Delta =  2.7291666666666634 %
#
#
# Test  g05_100.5
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1406 |                1436 |
# +----+--------------------+---------------------+
# |  1 |               1402 |                1436 |
# +----+--------------------+---------------------+
# |  2 |               1394 |                1436 |
# +----+--------------------+---------------------+
# |  3 |               1413 |                1436 |
# +----+--------------------+---------------------+
# |  4 |               1404 |                1436 |
# +----+--------------------+---------------------+
# |  5 |               1385 |                1436 |
# +----+--------------------+---------------------+
# |  6 |               1392 |                1436 |
# +----+--------------------+---------------------+
# |  7 |               1416 |                1436 |
# +----+--------------------+---------------------+
# |  8 |               1388 |                1436 |
# +----+--------------------+---------------------+
# |  9 |               1391 |                1436 |
# +----+--------------------+---------------------+
# | 10 |               1373 |                1436 |
# +----+--------------------+---------------------+
# | 11 |               1397 |                1436 |
# +----+--------------------+---------------------+
# | 12 |               1400 |                1436 |
# +----+--------------------+---------------------+
# | 13 |               1390 |                1436 |
# +----+--------------------+---------------------+
# | 14 |               1406 |                1436 |
# +----+--------------------+---------------------+
# | 15 |               1388 |                1436 |
# +----+--------------------+---------------------+
# | 16 |               1399 |                1436 |
# +----+--------------------+---------------------+
# | 17 |               1401 |                1436 |
# +----+--------------------+---------------------+
# | 18 |               1397 |                1436 |
# +----+--------------------+---------------------+
# | 19 |               1382 |                1436 |
# +----+--------------------+---------------------+
# | 20 |               1394 |                1436 |
# +----+--------------------+---------------------+
# | 21 |               1391 |                1436 |
# +----+--------------------+---------------------+
# | 22 |               1387 |                1436 |
# +----+--------------------+---------------------+
# | 23 |               1395 |                1436 |
# +----+--------------------+---------------------+
# | 24 |               1400 |                1436 |
# +----+--------------------+---------------------+
# | 25 |               1375 |                1436 |
# +----+--------------------+---------------------+
# | 26 |               1394 |                1436 |
# +----+--------------------+---------------------+
# | 27 |               1393 |                1436 |
# +----+--------------------+---------------------+
# | 28 |               1384 |                1436 |
# +----+--------------------+---------------------+
# | 29 |               1402 |                1436 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1394.6333333333334
# Giá trị chính xác:  1436
# Delta =  2.8806870937790086 %
#
#
# Test  g05_100.6
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1383 |                1434 |
# +----+--------------------+---------------------+
# |  1 |               1391 |                1434 |
# +----+--------------------+---------------------+
# |  2 |               1387 |                1434 |
# +----+--------------------+---------------------+
# |  3 |               1400 |                1434 |
# +----+--------------------+---------------------+
# |  4 |               1401 |                1434 |
# +----+--------------------+---------------------+
# |  5 |               1398 |                1434 |
# +----+--------------------+---------------------+
# |  6 |               1404 |                1434 |
# +----+--------------------+---------------------+
# |  7 |               1391 |                1434 |
# +----+--------------------+---------------------+
# |  8 |               1390 |                1434 |
# +----+--------------------+---------------------+
# |  9 |               1395 |                1434 |
# +----+--------------------+---------------------+
# | 10 |               1393 |                1434 |
# +----+--------------------+---------------------+
# | 11 |               1389 |                1434 |
# +----+--------------------+---------------------+
# | 12 |               1392 |                1434 |
# +----+--------------------+---------------------+
# | 13 |               1394 |                1434 |
# +----+--------------------+---------------------+
# | 14 |               1387 |                1434 |
# +----+--------------------+---------------------+
# | 15 |               1385 |                1434 |
# +----+--------------------+---------------------+
# | 16 |               1399 |                1434 |
# +----+--------------------+---------------------+
# | 17 |               1391 |                1434 |
# +----+--------------------+---------------------+
# | 18 |               1396 |                1434 |
# +----+--------------------+---------------------+
# | 19 |               1397 |                1434 |
# +----+--------------------+---------------------+
# | 20 |               1383 |                1434 |
# +----+--------------------+---------------------+
# | 21 |               1411 |                1434 |
# +----+--------------------+---------------------+
# | 22 |               1400 |                1434 |
# +----+--------------------+---------------------+
# | 23 |               1398 |                1434 |
# +----+--------------------+---------------------+
# | 24 |               1394 |                1434 |
# +----+--------------------+---------------------+
# | 25 |               1377 |                1434 |
# +----+--------------------+---------------------+
# | 26 |               1408 |                1434 |
# +----+--------------------+---------------------+
# | 27 |               1388 |                1434 |
# +----+--------------------+---------------------+
# | 28 |               1397 |                1434 |
# +----+--------------------+---------------------+
# | 29 |               1424 |                1434 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1394.7666666666667
# Giá trị chính xác:  1434
# Delta =  2.735936773593678 %
#
#
# Test  g05_100.7
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1405 |                1431 |
# +----+--------------------+---------------------+
# |  1 |               1394 |                1431 |
# +----+--------------------+---------------------+
# |  2 |               1376 |                1431 |
# +----+--------------------+---------------------+
# |  3 |               1392 |                1431 |
# +----+--------------------+---------------------+
# |  4 |               1412 |                1431 |
# +----+--------------------+---------------------+
# |  5 |               1407 |                1431 |
# +----+--------------------+---------------------+
# |  6 |               1381 |                1431 |
# +----+--------------------+---------------------+
# |  7 |               1387 |                1431 |
# +----+--------------------+---------------------+
# |  8 |               1391 |                1431 |
# +----+--------------------+---------------------+
# |  9 |               1421 |                1431 |
# +----+--------------------+---------------------+
# | 10 |               1391 |                1431 |
# +----+--------------------+---------------------+
# | 11 |               1387 |                1431 |
# +----+--------------------+---------------------+
# | 12 |               1401 |                1431 |
# +----+--------------------+---------------------+
# | 13 |               1411 |                1431 |
# +----+--------------------+---------------------+
# | 14 |               1396 |                1431 |
# +----+--------------------+---------------------+
# | 15 |               1415 |                1431 |
# +----+--------------------+---------------------+
# | 16 |               1390 |                1431 |
# +----+--------------------+---------------------+
# | 17 |               1395 |                1431 |
# +----+--------------------+---------------------+
# | 18 |               1393 |                1431 |
# +----+--------------------+---------------------+
# | 19 |               1384 |                1431 |
# +----+--------------------+---------------------+
# | 20 |               1402 |                1431 |
# +----+--------------------+---------------------+
# | 21 |               1381 |                1431 |
# +----+--------------------+---------------------+
# | 22 |               1392 |                1431 |
# +----+--------------------+---------------------+
# | 23 |               1401 |                1431 |
# +----+--------------------+---------------------+
# | 24 |               1405 |                1431 |
# +----+--------------------+---------------------+
# | 25 |               1382 |                1431 |
# +----+--------------------+---------------------+
# | 26 |               1399 |                1431 |
# +----+--------------------+---------------------+
# | 27 |               1393 |                1431 |
# +----+--------------------+---------------------+
# | 28 |               1392 |                1431 |
# +----+--------------------+---------------------+
# | 29 |               1398 |                1431 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1395.8
# Giá trị chính xác:  1431
# Delta =  2.459818308874916 %
#
#
# Test  g05_100.8
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1385 |                1432 |
# +----+--------------------+---------------------+
# |  1 |               1388 |                1432 |
# +----+--------------------+---------------------+
# |  2 |               1395 |                1432 |
# +----+--------------------+---------------------+
# |  3 |               1384 |                1432 |
# +----+--------------------+---------------------+
# |  4 |               1387 |                1432 |
# +----+--------------------+---------------------+
# |  5 |               1407 |                1432 |
# +----+--------------------+---------------------+
# |  6 |               1403 |                1432 |
# +----+--------------------+---------------------+
# |  7 |               1394 |                1432 |
# +----+--------------------+---------------------+
# |  8 |               1375 |                1432 |
# +----+--------------------+---------------------+
# |  9 |               1388 |                1432 |
# +----+--------------------+---------------------+
# | 10 |               1389 |                1432 |
# +----+--------------------+---------------------+
# | 11 |               1392 |                1432 |
# +----+--------------------+---------------------+
# | 12 |               1398 |                1432 |
# +----+--------------------+---------------------+
# | 13 |               1396 |                1432 |
# +----+--------------------+---------------------+
# | 14 |               1386 |                1432 |
# +----+--------------------+---------------------+
# | 15 |               1402 |                1432 |
# +----+--------------------+---------------------+
# | 16 |               1400 |                1432 |
# +----+--------------------+---------------------+
# | 17 |               1405 |                1432 |
# +----+--------------------+---------------------+
# | 18 |               1395 |                1432 |
# +----+--------------------+---------------------+
# | 19 |               1401 |                1432 |
# +----+--------------------+---------------------+
# | 20 |               1395 |                1432 |
# +----+--------------------+---------------------+
# | 21 |               1407 |                1432 |
# +----+--------------------+---------------------+
# | 22 |               1416 |                1432 |
# +----+--------------------+---------------------+
# | 23 |               1389 |                1432 |
# +----+--------------------+---------------------+
# | 24 |               1394 |                1432 |
# +----+--------------------+---------------------+
# | 25 |               1393 |                1432 |
# +----+--------------------+---------------------+
# | 26 |               1393 |                1432 |
# +----+--------------------+---------------------+
# | 27 |               1409 |                1432 |
# +----+--------------------+---------------------+
# | 28 |               1400 |                1432 |
# +----+--------------------+---------------------+
# | 29 |               1391 |                1432 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1395.2333333333333
# Giá trị chính xác:  1432
# Delta =  2.5675046554934813 %
#
#
# Test  g05_100.9
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |               1401 |                1430 |
# +----+--------------------+---------------------+
# |  1 |               1390 |                1430 |
# +----+--------------------+---------------------+
# |  2 |               1399 |                1430 |
# +----+--------------------+---------------------+
# |  3 |               1392 |                1430 |
# +----+--------------------+---------------------+
# |  4 |               1385 |                1430 |
# +----+--------------------+---------------------+
# |  5 |               1396 |                1430 |
# +----+--------------------+---------------------+
# |  6 |               1393 |                1430 |
# +----+--------------------+---------------------+
# |  7 |               1387 |                1430 |
# +----+--------------------+---------------------+
# |  8 |               1395 |                1430 |
# +----+--------------------+---------------------+
# |  9 |               1403 |                1430 |
# +----+--------------------+---------------------+
# | 10 |               1393 |                1430 |
# +----+--------------------+---------------------+
# | 11 |               1384 |                1430 |
# +----+--------------------+---------------------+
# | 12 |               1404 |                1430 |
# +----+--------------------+---------------------+
# | 13 |               1400 |                1430 |
# +----+--------------------+---------------------+
# | 14 |               1391 |                1430 |
# +----+--------------------+---------------------+
# | 15 |               1398 |                1430 |
# +----+--------------------+---------------------+
# | 16 |               1378 |                1430 |
# +----+--------------------+---------------------+
# | 17 |               1395 |                1430 |
# +----+--------------------+---------------------+
# | 18 |               1396 |                1430 |
# +----+--------------------+---------------------+
# | 19 |               1403 |                1430 |
# +----+--------------------+---------------------+
# | 20 |               1397 |                1430 |
# +----+--------------------+---------------------+
# | 21 |               1398 |                1430 |
# +----+--------------------+---------------------+
# | 22 |               1404 |                1430 |
# +----+--------------------+---------------------+
# | 23 |               1410 |                1430 |
# +----+--------------------+---------------------+
# | 24 |               1389 |                1430 |
# +----+--------------------+---------------------+
# | 25 |               1396 |                1430 |
# +----+--------------------+---------------------+
# | 26 |               1389 |                1430 |
# +----+--------------------+---------------------+
# | 27 |               1386 |                1430 |
# +----+--------------------+---------------------+
# | 28 |               1392 |                1430 |
# +----+--------------------+---------------------+
# | 29 |               1395 |                1430 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  1394.6333333333334
# Giá trị chính xác:  1430
# Delta =  2.473193473193466 %
#
#
# Test  g05_60.0
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                529 |                 536 |
# +----+--------------------+---------------------+
# |  1 |                523 |                 536 |
# +----+--------------------+---------------------+
# |  2 |                531 |                 536 |
# +----+--------------------+---------------------+
# |  3 |                528 |                 536 |
# +----+--------------------+---------------------+
# |  4 |                536 |                 536 |
# +----+--------------------+---------------------+
# |  5 |                524 |                 536 |
# +----+--------------------+---------------------+
# |  6 |                524 |                 536 |
# +----+--------------------+---------------------+
# |  7 |                524 |                 536 |
# +----+--------------------+---------------------+
# |  8 |                517 |                 536 |
# +----+--------------------+---------------------+
# |  9 |                530 |                 536 |
# +----+--------------------+---------------------+
# | 10 |                526 |                 536 |
# +----+--------------------+---------------------+
# | 11 |                526 |                 536 |
# +----+--------------------+---------------------+
# | 12 |                521 |                 536 |
# +----+--------------------+---------------------+
# | 13 |                519 |                 536 |
# +----+--------------------+---------------------+
# | 14 |                533 |                 536 |
# +----+--------------------+---------------------+
# | 15 |                534 |                 536 |
# +----+--------------------+---------------------+
# | 16 |                528 |                 536 |
# +----+--------------------+---------------------+
# | 17 |                522 |                 536 |
# +----+--------------------+---------------------+
# | 18 |                524 |                 536 |
# +----+--------------------+---------------------+
# | 19 |                529 |                 536 |
# +----+--------------------+---------------------+
# | 20 |                525 |                 536 |
# +----+--------------------+---------------------+
# | 21 |                524 |                 536 |
# +----+--------------------+---------------------+
# | 22 |                519 |                 536 |
# +----+--------------------+---------------------+
# | 23 |                528 |                 536 |
# +----+--------------------+---------------------+
# | 24 |                526 |                 536 |
# +----+--------------------+---------------------+
# | 25 |                521 |                 536 |
# +----+--------------------+---------------------+
# | 26 |                525 |                 536 |
# +----+--------------------+---------------------+
# | 27 |                524 |                 536 |
# +----+--------------------+---------------------+
# | 28 |                530 |                 536 |
# +----+--------------------+---------------------+
# | 29 |                533 |                 536 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  526.1
# Giá trị chính xác:  536
# Delta =  1.84701492537313 %
#
#
# Test  g05_60.1
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                521 |                 532 |
# +----+--------------------+---------------------+
# |  1 |                520 |                 532 |
# +----+--------------------+---------------------+
# |  2 |                517 |                 532 |
# +----+--------------------+---------------------+
# |  3 |                517 |                 532 |
# +----+--------------------+---------------------+
# |  4 |                518 |                 532 |
# +----+--------------------+---------------------+
# |  5 |                528 |                 532 |
# +----+--------------------+---------------------+
# |  6 |                519 |                 532 |
# +----+--------------------+---------------------+
# |  7 |                509 |                 532 |
# +----+--------------------+---------------------+
# |  8 |                513 |                 532 |
# +----+--------------------+---------------------+
# |  9 |                524 |                 532 |
# +----+--------------------+---------------------+
# | 10 |                525 |                 532 |
# +----+--------------------+---------------------+
# | 11 |                525 |                 532 |
# +----+--------------------+---------------------+
# | 12 |                515 |                 532 |
# +----+--------------------+---------------------+
# | 13 |                520 |                 532 |
# +----+--------------------+---------------------+
# | 14 |                523 |                 532 |
# +----+--------------------+---------------------+
# | 15 |                531 |                 532 |
# +----+--------------------+---------------------+
# | 16 |                530 |                 532 |
# +----+--------------------+---------------------+
# | 17 |                519 |                 532 |
# +----+--------------------+---------------------+
# | 18 |                512 |                 532 |
# +----+--------------------+---------------------+
# | 19 |                525 |                 532 |
# +----+--------------------+---------------------+
# | 20 |                527 |                 532 |
# +----+--------------------+---------------------+
# | 21 |                519 |                 532 |
# +----+--------------------+---------------------+
# | 22 |                527 |                 532 |
# +----+--------------------+---------------------+
# | 23 |                514 |                 532 |
# +----+--------------------+---------------------+
# | 24 |                516 |                 532 |
# +----+--------------------+---------------------+
# | 25 |                519 |                 532 |
# +----+--------------------+---------------------+
# | 26 |                527 |                 532 |
# +----+--------------------+---------------------+
# | 27 |                523 |                 532 |
# +----+--------------------+---------------------+
# | 28 |                516 |                 532 |
# +----+--------------------+---------------------+
# | 29 |                517 |                 532 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  520.5333333333333
# Giá trị chính xác:  532
# Delta =  2.1553884711779507 %
#
#
# Test  g05_60.2
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                522 |                 529 |
# +----+--------------------+---------------------+
# |  1 |                521 |                 529 |
# +----+--------------------+---------------------+
# |  2 |                519 |                 529 |
# +----+--------------------+---------------------+
# |  3 |                518 |                 529 |
# +----+--------------------+---------------------+
# |  4 |                521 |                 529 |
# +----+--------------------+---------------------+
# |  5 |                523 |                 529 |
# +----+--------------------+---------------------+
# |  6 |                519 |                 529 |
# +----+--------------------+---------------------+
# |  7 |                519 |                 529 |
# +----+--------------------+---------------------+
# |  8 |                519 |                 529 |
# +----+--------------------+---------------------+
# |  9 |                529 |                 529 |
# +----+--------------------+---------------------+
# | 10 |                525 |                 529 |
# +----+--------------------+---------------------+
# | 11 |                517 |                 529 |
# +----+--------------------+---------------------+
# | 12 |                519 |                 529 |
# +----+--------------------+---------------------+
# | 13 |                522 |                 529 |
# +----+--------------------+---------------------+
# | 14 |                526 |                 529 |
# +----+--------------------+---------------------+
# | 15 |                527 |                 529 |
# +----+--------------------+---------------------+
# | 16 |                519 |                 529 |
# +----+--------------------+---------------------+
# | 17 |                523 |                 529 |
# +----+--------------------+---------------------+
# | 18 |                527 |                 529 |
# +----+--------------------+---------------------+
# | 19 |                520 |                 529 |
# +----+--------------------+---------------------+
# | 20 |                521 |                 529 |
# +----+--------------------+---------------------+
# | 21 |                514 |                 529 |
# +----+--------------------+---------------------+
# | 22 |                512 |                 529 |
# +----+--------------------+---------------------+
# | 23 |                528 |                 529 |
# +----+--------------------+---------------------+
# | 24 |                522 |                 529 |
# +----+--------------------+---------------------+
# | 25 |                514 |                 529 |
# +----+--------------------+---------------------+
# | 26 |                519 |                 529 |
# +----+--------------------+---------------------+
# | 27 |                515 |                 529 |
# +----+--------------------+---------------------+
# | 28 |                518 |                 529 |
# +----+--------------------+---------------------+
# | 29 |                511 |                 529 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  520.3
# Giá trị chính xác:  529
# Delta =  1.644612476370519 %
#
#
# Test  g05_60.3
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                522 |                 538 |
# +----+--------------------+---------------------+
# |  1 |                521 |                 538 |
# +----+--------------------+---------------------+
# |  2 |                526 |                 538 |
# +----+--------------------+---------------------+
# |  3 |                528 |                 538 |
# +----+--------------------+---------------------+
# |  4 |                526 |                 538 |
# +----+--------------------+---------------------+
# |  5 |                523 |                 538 |
# +----+--------------------+---------------------+
# |  6 |                525 |                 538 |
# +----+--------------------+---------------------+
# |  7 |                518 |                 538 |
# +----+--------------------+---------------------+
# |  8 |                529 |                 538 |
# +----+--------------------+---------------------+
# |  9 |                535 |                 538 |
# +----+--------------------+---------------------+
# | 10 |                526 |                 538 |
# +----+--------------------+---------------------+
# | 11 |                528 |                 538 |
# +----+--------------------+---------------------+
# | 12 |                513 |                 538 |
# +----+--------------------+---------------------+
# | 13 |                523 |                 538 |
# +----+--------------------+---------------------+
# | 14 |                529 |                 538 |
# +----+--------------------+---------------------+
# | 15 |                528 |                 538 |
# +----+--------------------+---------------------+
# | 16 |                516 |                 538 |
# +----+--------------------+---------------------+
# | 17 |                525 |                 538 |
# +----+--------------------+---------------------+
# | 18 |                525 |                 538 |
# +----+--------------------+---------------------+
# | 19 |                518 |                 538 |
# +----+--------------------+---------------------+
# | 20 |                523 |                 538 |
# +----+--------------------+---------------------+
# | 21 |                523 |                 538 |
# +----+--------------------+---------------------+
# | 22 |                524 |                 538 |
# +----+--------------------+---------------------+
# | 23 |                526 |                 538 |
# +----+--------------------+---------------------+
# | 24 |                532 |                 538 |
# +----+--------------------+---------------------+
# | 25 |                513 |                 538 |
# +----+--------------------+---------------------+
# | 26 |                525 |                 538 |
# +----+--------------------+---------------------+
# | 27 |                536 |                 538 |
# +----+--------------------+---------------------+
# | 28 |                538 |                 538 |
# +----+--------------------+---------------------+
# | 29 |                518 |                 538 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  524.7333333333333
# Giá trị chính xác:  538
# Delta =  2.465923172242872 %
#
#
# Test  g05_60.4
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                520 |                 527 |
# +----+--------------------+---------------------+
# |  1 |                517 |                 527 |
# +----+--------------------+---------------------+
# |  2 |                516 |                 527 |
# +----+--------------------+---------------------+
# |  3 |                525 |                 527 |
# +----+--------------------+---------------------+
# |  4 |                527 |                 527 |
# +----+--------------------+---------------------+
# |  5 |                520 |                 527 |
# +----+--------------------+---------------------+
# |  6 |                521 |                 527 |
# +----+--------------------+---------------------+
# |  7 |                520 |                 527 |
# +----+--------------------+---------------------+
# |  8 |                515 |                 527 |
# +----+--------------------+---------------------+
# |  9 |                524 |                 527 |
# +----+--------------------+---------------------+
# | 10 |                517 |                 527 |
# +----+--------------------+---------------------+
# | 11 |                521 |                 527 |
# +----+--------------------+---------------------+
# | 12 |                519 |                 527 |
# +----+--------------------+---------------------+
# | 13 |                515 |                 527 |
# +----+--------------------+---------------------+
# | 14 |                520 |                 527 |
# +----+--------------------+---------------------+
# | 15 |                521 |                 527 |
# +----+--------------------+---------------------+
# | 16 |                523 |                 527 |
# +----+--------------------+---------------------+
# | 17 |                513 |                 527 |
# +----+--------------------+---------------------+
# | 18 |                524 |                 527 |
# +----+--------------------+---------------------+
# | 19 |                515 |                 527 |
# +----+--------------------+---------------------+
# | 20 |                524 |                 527 |
# ...
# |  2 |                906 |                 926 |
# +----+--------------------+---------------------+
# |  3 |                902 |                 926 |
# +----+--------------------+---------------------+
# |  4 |                902 |                 926 |
# +----+--------------------+---------------------+
# |  5 |                914 |                 926 |
# +----+--------------------+---------------------+
# |  6 |                904 |                 926 |
# +----+--------------------+---------------------+
# |  7 |                909 |                 926 |
# +----+--------------------+---------------------+
# |  8 |                907 |                 926 |
# +----+--------------------+---------------------+
# |  9 |                909 |                 926 |
# +----+--------------------+---------------------+
# | 10 |                905 |                 926 |
# +----+--------------------+---------------------+
# | 11 |                901 |                 926 |
# +----+--------------------+---------------------+
# | 12 |                905 |                 926 |
# +----+--------------------+---------------------+
# | 13 |                903 |                 926 |
# +----+--------------------+---------------------+
# | 14 |                892 |                 926 |
# +----+--------------------+---------------------+
# | 15 |                905 |                 926 |
# +----+--------------------+---------------------+
# | 16 |                898 |                 926 |
# +----+--------------------+---------------------+
# | 17 |                900 |                 926 |
# +----+--------------------+---------------------+
# | 18 |                904 |                 926 |
# +----+--------------------+---------------------+
# | 19 |                900 |                 926 |
# +----+--------------------+---------------------+
# | 20 |                892 |                 926 |
# +----+--------------------+---------------------+
# | 21 |                905 |                 926 |
# +----+--------------------+---------------------+
# | 22 |                893 |                 926 |
# +----+--------------------+---------------------+
# | 23 |                901 |                 926 |
# +----+--------------------+---------------------+
# | 24 |                906 |                 926 |
# +----+--------------------+---------------------+
# | 25 |                899 |                 926 |
# +----+--------------------+---------------------+
# | 26 |                901 |                 926 |
# +----+--------------------+---------------------+
# | 27 |                911 |                 926 |
# +----+--------------------+---------------------+
# | 28 |                909 |                 926 |
# +----+--------------------+---------------------+
# | 29 |                907 |                 926 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  903.5666666666667
# Giá trị chính xác:  926
# Delta =  2.422606191504674 %
#
#
# Test  g05_80.6
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                901 |                 929 |
# +----+--------------------+---------------------+
# |  1 |                908 |                 929 |
# +----+--------------------+---------------------+
# |  2 |                908 |                 929 |
# +----+--------------------+---------------------+
# |  3 |                917 |                 929 |
# +----+--------------------+---------------------+
# |  4 |                901 |                 929 |
# +----+--------------------+---------------------+
# |  5 |                914 |                 929 |
# +----+--------------------+---------------------+
# |  6 |                898 |                 929 |
# +----+--------------------+---------------------+
# |  7 |                911 |                 929 |
# +----+--------------------+---------------------+
# |  8 |                907 |                 929 |
# +----+--------------------+---------------------+
# |  9 |                910 |                 929 |
# +----+--------------------+---------------------+
# | 10 |                905 |                 929 |
# +----+--------------------+---------------------+
# | 11 |                913 |                 929 |
# +----+--------------------+---------------------+
# | 12 |                906 |                 929 |
# +----+--------------------+---------------------+
# | 13 |                899 |                 929 |
# +----+--------------------+---------------------+
# | 14 |                898 |                 929 |
# +----+--------------------+---------------------+
# | 15 |                919 |                 929 |
# +----+--------------------+---------------------+
# | 16 |                904 |                 929 |
# +----+--------------------+---------------------+
# | 17 |                914 |                 929 |
# +----+--------------------+---------------------+
# | 18 |                908 |                 929 |
# +----+--------------------+---------------------+
# | 19 |                905 |                 929 |
# +----+--------------------+---------------------+
# | 20 |                909 |                 929 |
# +----+--------------------+---------------------+
# | 21 |                901 |                 929 |
# +----+--------------------+---------------------+
# | 22 |                914 |                 929 |
# +----+--------------------+---------------------+
# | 23 |                897 |                 929 |
# +----+--------------------+---------------------+
# | 24 |                910 |                 929 |
# +----+--------------------+---------------------+
# | 25 |                906 |                 929 |
# +----+--------------------+---------------------+
# | 26 |                899 |                 929 |
# +----+--------------------+---------------------+
# | 27 |                916 |                 929 |
# +----+--------------------+---------------------+
# | 28 |                907 |                 929 |
# +----+--------------------+---------------------+
# | 29 |                913 |                 929 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  907.2666666666667
# Giá trị chính xác:  929
# Delta =  2.3394330821672065 %
#
#
# Test  g05_80.7
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                911 |                 929 |
# +----+--------------------+---------------------+
# |  1 |                910 |                 929 |
# +----+--------------------+---------------------+
# |  2 |                910 |                 929 |
# +----+--------------------+---------------------+
# |  3 |                906 |                 929 |
# +----+--------------------+---------------------+
# |  4 |                908 |                 929 |
# +----+--------------------+---------------------+
# |  5 |                903 |                 929 |
# +----+--------------------+---------------------+
# |  6 |                902 |                 929 |
# +----+--------------------+---------------------+
# |  7 |                914 |                 929 |
# +----+--------------------+---------------------+
# |  8 |                904 |                 929 |
# +----+--------------------+---------------------+
# |  9 |                908 |                 929 |
# +----+--------------------+---------------------+
# | 10 |                919 |                 929 |
# +----+--------------------+---------------------+
# | 11 |                899 |                 929 |
# +----+--------------------+---------------------+
# | 12 |                912 |                 929 |
# +----+--------------------+---------------------+
# | 13 |                901 |                 929 |
# +----+--------------------+---------------------+
# | 14 |                914 |                 929 |
# +----+--------------------+---------------------+
# | 15 |                908 |                 929 |
# +----+--------------------+---------------------+
# | 16 |                916 |                 929 |
# +----+--------------------+---------------------+
# | 17 |                912 |                 929 |
# +----+--------------------+---------------------+
# | 18 |                901 |                 929 |
# +----+--------------------+---------------------+
# | 19 |                891 |                 929 |
# +----+--------------------+---------------------+
# | 20 |                909 |                 929 |
# +----+--------------------+---------------------+
# | 21 |                900 |                 929 |
# +----+--------------------+---------------------+
# | 22 |                905 |                 929 |
# +----+--------------------+---------------------+
# | 23 |                919 |                 929 |
# +----+--------------------+---------------------+
# | 24 |                908 |                 929 |
# +----+--------------------+---------------------+
# | 25 |                907 |                 929 |
# +----+--------------------+---------------------+
# | 26 |                907 |                 929 |
# +----+--------------------+---------------------+
# | 27 |                905 |                 929 |
# +----+--------------------+---------------------+
# | 28 |                920 |                 929 |
# +----+--------------------+---------------------+
# | 29 |                906 |                 929 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  907.8333333333334
# Giá trị chính xác:  929
# Delta =  2.278435593828485 %
#
#
# Test  g05_80.8
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                903 |                 925 |
# +----+--------------------+---------------------+
# |  1 |                904 |                 925 |
# +----+--------------------+---------------------+
# |  2 |                896 |                 925 |
# +----+--------------------+---------------------+
# |  3 |                901 |                 925 |
# +----+--------------------+---------------------+
# |  4 |                907 |                 925 |
# +----+--------------------+---------------------+
# |  5 |                913 |                 925 |
# +----+--------------------+---------------------+
# |  6 |                898 |                 925 |
# +----+--------------------+---------------------+
# |  7 |                909 |                 925 |
# +----+--------------------+---------------------+
# |  8 |                901 |                 925 |
# +----+--------------------+---------------------+
# |  9 |                897 |                 925 |
# +----+--------------------+---------------------+
# | 10 |                889 |                 925 |
# +----+--------------------+---------------------+
# | 11 |                907 |                 925 |
# +----+--------------------+---------------------+
# | 12 |                898 |                 925 |
# +----+--------------------+---------------------+
# | 13 |                908 |                 925 |
# +----+--------------------+---------------------+
# | 14 |                892 |                 925 |
# +----+--------------------+---------------------+
# | 15 |                916 |                 925 |
# +----+--------------------+---------------------+
# | 16 |                896 |                 925 |
# +----+--------------------+---------------------+
# | 17 |                915 |                 925 |
# +----+--------------------+---------------------+
# | 18 |                909 |                 925 |
# +----+--------------------+---------------------+
# | 19 |                897 |                 925 |
# +----+--------------------+---------------------+
# | 20 |                907 |                 925 |
# +----+--------------------+---------------------+
# | 21 |                894 |                 925 |
# +----+--------------------+---------------------+
# | 22 |                904 |                 925 |
# +----+--------------------+---------------------+
# | 23 |                905 |                 925 |
# +----+--------------------+---------------------+
# | 24 |                901 |                 925 |
# +----+--------------------+---------------------+
# | 25 |                895 |                 925 |
# +----+--------------------+---------------------+
# | 26 |                901 |                 925 |
# +----+--------------------+---------------------+
# | 27 |                903 |                 925 |
# +----+--------------------+---------------------+
# | 28 |                907 |                 925 |
# +----+--------------------+---------------------+
# | 29 |                906 |                 925 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  902.6333333333333
# Giá trị chính xác:  925
# Delta =  2.418018018018019 %
#
#
# Test  g05_80.9
# +----+--------------------+---------------------+
# |    |   Giá trị tìm được |   Giá trị chính xác |
# +====+====================+=====================+
# |  0 |                902 |                 923 |
# +----+--------------------+---------------------+
# |  1 |                892 |                 923 |
# +----+--------------------+---------------------+
# |  2 |                908 |                 923 |
# +----+--------------------+---------------------+
# |  3 |                919 |                 923 |
# +----+--------------------+---------------------+
# |  4 |                910 |                 923 |
# +----+--------------------+---------------------+
# |  5 |                900 |                 923 |
# +----+--------------------+---------------------+
# |  6 |                896 |                 923 |
# +----+--------------------+---------------------+
# |  7 |                891 |                 923 |
# +----+--------------------+---------------------+
# |  8 |                898 |                 923 |
# +----+--------------------+---------------------+
# |  9 |                905 |                 923 |
# +----+--------------------+---------------------+
# | 10 |                901 |                 923 |
# +----+--------------------+---------------------+
# | 11 |                905 |                 923 |
# +----+--------------------+---------------------+
# | 12 |                905 |                 923 |
# +----+--------------------+---------------------+
# | 13 |                906 |                 923 |
# +----+--------------------+---------------------+
# | 14 |                901 |                 923 |
# +----+--------------------+---------------------+
# | 15 |                900 |                 923 |
# +----+--------------------+---------------------+
# | 16 |                903 |                 923 |
# +----+--------------------+---------------------+
# | 17 |                904 |                 923 |
# +----+--------------------+---------------------+
# | 18 |                907 |                 923 |
# +----+--------------------+---------------------+
# | 19 |                901 |                 923 |
# +----+--------------------+---------------------+
# | 20 |                905 |                 923 |
# +----+--------------------+---------------------+
# | 21 |                910 |                 923 |
# +----+--------------------+---------------------+
# | 22 |                902 |                 923 |
# +----+--------------------+---------------------+
# | 23 |                904 |                 923 |
# +----+--------------------+---------------------+
# | 24 |                905 |                 923 |
# +----+--------------------+---------------------+
# | 25 |                894 |                 923 |
# +----+--------------------+---------------------+
# | 26 |                919 |                 923 |
# +----+--------------------+---------------------+
# | 27 |                906 |                 923 |
# +----+--------------------+---------------------+
# | 28 |                908 |                 923 |
# +----+--------------------+---------------------+
# | 29 |                905 |                 923 |
# +----+--------------------+---------------------+
# Trung bình giá trị tìm được:  903.7333333333333
# Giá trị chính xác:  923
# Delta =  2.0873961719032126 %
